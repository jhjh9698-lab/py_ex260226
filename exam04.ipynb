# %%
print('== 예제 1 ==')
S = '안녕하세요.'
#   [0,1,2,3,4]

print('== s길이 출력 ==')
print(len(s))

# s[start:end(-1):step]
print('s를 이루는 문자 중에서 앞에 거 2개 출력')
print(s[0:2])

print('s를 이루는 문장 중에서 문자 하나 건너뛰고 1개 출력')
print(s[1:2])

print('s를 이루는 문장 중에서 문자 4개 출력, 첫 인덱스 생략')
print(s[:4])

print('s를 이루는 문장에서 앞에 문자 3개 건너뛰고, 나머지 전부 출력, len')
print(s[3:len(s)])

print('s를 이루는 문장에서 앞에 문자 3개 건너뛰고, 뒤 인텍스 생략')
print(s[3:])

print('s를 이루는 문장를 하나씩 출력, while')
i = 0
while i < len(s):
    print(s[i])
    i += 1

print('s를 이루는 문장를 역순으로 하나씩 출력, while')
i = len(s) - 1
while i < len(s):
    print(s[i])
    i -= 1

print('s를 이루는 문장를 하나씩 출력, for')  
for c in s:
    print(c)
# Out:
# == 예제 1 ==
# == s길이 출력 ==
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 #   [0,1,2,3,4]
#       5 print('== s길이 출력 ==')
# ----> 6 print(len(s))
#       8 # s[start:end(-1):step]
#       9 print('s를 이루는 문자 중에서 앞에 거 2개 출력')
#
# NameError: name 's' is not defined

# %%
print('== 예제3 ==')
s = 'a안b녕c하d세e요f'

print('s를 이루는 문장중에서 한글만 출력')
print(s[1] +s[3] + s[5]+ s[7] + s[9])

print('s를 이루는 문장중에서 한글만 출력, for, if, or, comtiue, 방법 1')
for c in s:
    if c =='a' or c == 'b' or c == 'c' or c == 'd' or c == 'e' or c == 'f':
        continue
print(c)


print('s를 이루는 문장중에서 한글만 출력, for, if, or, comtiue, 방법 2')
for c in s:
    if c !='a' and c == 'b' and c == 'c' and c == 'd' and c == 'e' and c == 'f':
        print(c)
# Out:
# == 예제3 ==
# s를 이루는 문장중에서 한글만 출력
# 안녕하세요
# s를 이루는 문장중에서 한글만 출력, for, if, or, comtiue, 방법 1
# f

# %%
#문자열 기초 종합 문제

print("== 예제 1 ==")
s = "안녕하세요."

print("s의 길이 출력")
print(len(s))

print("s를 이루는 문장 중에서 앞에 거, 2개 출력")
print(s[0:2])

print("s를 이루는 문장 중에서 앞에 문자 하나 건너 뛰고 1개 출력")
print(s[1:2])

print("s를 이루는 문장 중에서 앞에 문자 4개 출력, 첫 인덱스 생략")
print(s[:4])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 나머지 전부 출력, len")
print(s[3:len(s)])

print("s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 뒤 인덱스 생략")
print(s[3:])


print("== 예제 2 ==")
s = "안녕하세요"

print("s를 이루는 문자를 하나씩 출력, while")
i = 0
while i < len(s):
    print(s[i])
    i += 1

print("s를 이루는 문자를 역순으로 하나씩 출력, while")
i = len(s) - 1
while i >= 0:
    print(s[i])
    i -= 1

print("s를 이루는 문자를 하나씩 출력, for")
for c in s:
  print(c)


print("== 예제 3 ==")
s = "a안b녕c하d세e요f"

print("s를 이루는 문장 중에서 한글만 출력")
print(s[1] + s[3] + s[5] + s[7] + s[9])

print("s를 이루는 문장 중에서 한글만 출력, for, if, or, continue, 방법 1")
for c in s:
    if c == 'a' or c == 'b' or c == 'c' or c == 'd' or c == 'e' or c == 'f':
        continue
    print(c)

print("s를 이루는 문장 중에서 한글만 출력, for, if and, 방법 2")
for c in s:
    if c != 'a' and c != 'b' and c != 'c' and c != 'd' and c != 'e' and c != 'f':
        print(c)

print("s를 이루는 문장 중에서 한글만 출력, for, not in, 방법 3")
for c in s:
    if c not in ['a', 'b', 'c', 'd', 'e', 'f']:
        print(c)
# Out:
# == 예제 1 ==
# s의 길이 출력
# 6
# s를 이루는 문장 중에서 앞에 거, 2개 출력
# 안녕
# s를 이루는 문장 중에서 앞에 문자 하나 건너 뛰고 1개 출력
# 녕
# s를 이루는 문장 중에서 앞에 문자 4개 출력, 첫 인덱스 생략
# 안녕하세
# s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 나머지 전부 출력, len
# 세요.
# s를 이루는 문장 중에서 앞에 문자 3개 건너 뛰고, 뒤 인덱스 생략
# 세요.
# == 예제 2 ==
# s를 이루는 문자를 하나씩 출력, while
# 안
# 녕
# 하
# 세
# 요
# s를 이루는 문자를 역순으로 하나씩 출력, while
# 요
# 세
# 하
# 녕
# 안
# s를 이루는 문자를 하나씩 출력, for
# 안
# 녕
# 하
# 세
# 요
# == 예제 3 ==
# s를 이루는 문장 중에서 한글만 출력
# 안녕하세요
# s를 이루는 문장 중에서 한글만 출력, for, if, or, continue, 방법 1
# 안
# 녕
# 하
# 세
# 요
# s를 이루는 문장 중에서 한글만 출력, for, if and, 방법 2
# 안
# 녕
# 하
# 세
# 요
# s를 이루는 문장 중에서 한글만 출력, for, not in, 방법 3
# 안
# 녕
# 하
# 세
# 요
