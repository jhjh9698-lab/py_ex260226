# %%
# import : 파일 불러오기
import ex1

ex1.fun1()
# Out:
# '모듈에 있는 첫번째 함수'

# %%
from ex1 import fun1, fun2

# fun1()
# fun2()
# 이런식으로만 호출하면 마지막 것만 출력
# 안되는 경우 다시 vscode를 껐다 키면 됨

print(fun1())
print(fun2())
# Out:
# 모듈에 있는 첫번째 함수
# 1

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\202-25\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\202-25\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\202-25\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\202-25\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\202-25\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\202-25\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages']
